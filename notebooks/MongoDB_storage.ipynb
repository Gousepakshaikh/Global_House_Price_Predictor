# %%
import pymongo
import pandas as pd

# %%
df=pd.read_csv('data.csv')
df.shape
# Out:
# (50000, 25)

# %%
df
# Out:
#        property_id    country       city      property_type furnishing_status  \
# 0            50199     Canada   Montreal  Independent House       Unfurnished
# 1            54477        USA    Chicago             Studio       Unfurnished
# 2            70488  Australia   Brisbane  Independent House   Fully-Furnished
# 3            28338      China    Beijing              Villa   Fully-Furnished
# 4            99655      India       Pune  Independent House    Semi-Furnished
# ...            ...        ...        ...                ...               ...
# 49995        12335  Australia   Brisbane          Apartment    Semi-Furnished
# 49996       163351     Brazil  São Paulo          Townhouse    Semi-Furnished
# 49997        65958  Australia  Melbourne          Apartment    Semi-Furnished
# 49998       195706        USA   New York              Villa   Fully-Furnished
# 49999        69974  Australia  Melbourne             Studio    Semi-Furnished
#
# ...

# %%
data=df.to_dict(orient='records')

# %%
client=pymongo.MongoClient("mongodb+srv://gousepakshaikh14112002_db_user:aZxC3JJcMZqoBqkW@cluster0.zi2j3sp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
data_base=client["House"]
collection=data_base["House-Data"]

# %%
rec=collection.insert_many(data)
